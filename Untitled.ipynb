# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

print("Imported sucessfully")
# Out:
# Imported sucessfully

# %%
X = pd.read_csv("datasets/loan_prediction/train.csv")
test = pd.read_csv("datasets/loan_prediction/test.csv")
print(X.shape, test.shape)
X = pd.concat(test)
print(X.shape)
# Out:
# (614, 13) (367, 12)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 test = pd.read_csv("datasets/loan_prediction/test.csv")
#       3 print(X.shape, test.shape)
# ----> 4 X = pd.concat(test)
#       5 print(X.shape)
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File ~/.local/lib/python3.13/site-packages/pandas/core/reshape/concat.py:800, in _clean_keys_and_objs(objs, keys)
#     798     objs = [objs[k] for k in keys]
#     799 elif isinstance(objs, (ABCSeries, ABCDataFrame)) or is_scalar(objs):
# --> 800     raise TypeError(
#     801         "first argument must be an iterable of pandas "
#     802         f'objects, you passed an object of type "{type(objs).__name__}"'
#     803     )
#     804 elif not isinstance(objs, abc.Sized):
#     805     objs = list(objs)
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"
